# %% [markdown]
# # 02 — Modelagem: Classificação de Risco de Atraso
#
# Treinamento e avaliação do modelo Random Forest para predição da classe de atraso dos discentes.

# %%
import sys
sys.path.append('..')

from src.models.train import treinar
from src.models.predict import prever

# %%
# Treina o modelo
treinar()

# %%
# Exemplo de predição para um novo aluno
resultado = prever({'ano_ingresso': 2023, 'ingressou_periodo_2': 0})
print('Classe prevista:', resultado['classe'])
print('Probabilidades:', resultado['probabilidades'])
